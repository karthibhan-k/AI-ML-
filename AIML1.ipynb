# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Read dataset
df = pd.read_csv('Loan-Approval-Prediction.csv')
print(df.head())

# Remove Loan_ID because it is not useful for prediction
df = df.drop(columns=['Loan_ID'])

# Handle missing values
df = df.dropna()

# Convert categorical columns into numbers
df = pd.get_dummies(df, columns=[
    'Gender',
    'Married',
    'Dependents',
    'Education',
    'Self_Employed',
    'Property_Area'
])

# Convert target variable
df['Loan_Status'] = df['Loan_Status'].map({'Y': 1, 'N': 0})

# Define target variable
y = df['Loan_Status']

# Define feature matrix
x = df.drop(columns=['Loan_Status'])

# Train-test split
x_train, x_test, y_train, y_test = train_test_split(
    x, y,
    test_size=0.2,
    random_state=42,
    stratify=y
)

# Feature scaling
scalar = StandardScaler()

x_train = scalar.fit_transform(x_train)
x_test = scalar.transform(x_test)

# Create neural network
model = Sequential([
    Dense(16, activation="relu", input_shape=(x_train.shape[1],)),
    Dense(8, activation="relu"),
    Dense(1, activation="sigmoid")
])

# Compile the model
model.compile(
    optimizer="adam",
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

# Train the model
model.fit(
    x_train,
    y_train,
    epochs=20,
    batch_size=16,
    verbose=1
)

# Predict first test sample
prediction = model.predict(x_test[:1], verbose=1)

probability = prediction[0][0]

print("\nPrediction Probability:", probability)

if probability >= 0.5:
    print("Prediction Class: 1")
    print("Meaning: Loan Approved")
else:
    print("Prediction Class: 0")
    print("Meaning: Loan Not Approved")
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y
# /usr/local/lib/python3.13/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6276 - loss: 0.7263
# Epoch 2/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6536 - loss: 0.6790
# Epoch 3/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6745 - loss: 0.6460
# Epoch 4/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6979 - loss: 0.6213
# Epoch 5/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7031 - loss: 0.6009
# Epoch 6/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7161 - loss: 0.5828
# Epoch 7/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7240 - loss: 0.5673
# Epoch 8/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7448 - loss: 0.5524
# Epoch 9/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7474 - loss: 0.5401
# Epoch 10/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7500 - loss: 0.5283
# Epoch 11/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7526 - loss: 0.5191
# Epoch 12/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7630 - loss: 0.5096
# Epoch 13/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7734 - loss: 0.5019
# Epoch 14/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7760 - loss: 0.4932
# Epoch 15/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7812 - loss: 0.4850
# Epoch 16/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7891 - loss: 0.4772
# Epoch 17/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7995 - loss: 0.4704
# Epoch 18/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8073 - loss: 0.4640
# Epoch 19/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8047 - loss: 0.4572
# Epoch 20/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8099 - loss: 0.4513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
#
# Prediction Probability: 0.8767681
# Prediction Class: 1
# Meaning: Loan Approved
